# %%
import time

# Linear Search Function
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1


# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    value = int(input(f"Element {i + 1}: "))
    arr.append(value)

target = int(input("Enter the element to search: "))

print("\nArray:", arr)
print("Element to search:", target)

# Start execution time
start_time = time.perf_counter()

# Perform Linear Search
result = linear_search(arr, target)

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if result != -1:
    print(f"Element {target} found at index {result}")
else:
    print(f"Element {target} not found")

print("Execution Time: {:.10f} seconds".format(execution_time))

# Time Complexity
print("\n--- Time Complexity Analysis ---")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 8
# Enter the elements:
# Element 1: 5
# Element 2: 6
# Element 3: 8
# Element 4: 1
# Element 5: 12
# Element 6: 21
# Element 7: 6
# Element 8: 45
# Enter the element to search: 1
#
# Array: [5, 6, 8, 1, 12, 21, 6, 45]
# Element to search: 1
# Element 1 found at index 3
# Execution Time: 0.0000791240 seconds
#
# --- Time Complexity Analysis ---
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
# Space Complexity: O(1)

# %%
import time

# Binary Search Function
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == target:
            return mid

        elif arr[mid] < target:
            low = mid + 1

        else:
            high = mid - 1

    return -1


# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements in sorted order:")
for i in range(n):
    value = int(input(f"Element {i + 1}: "))
    arr.append(value)

target = int(input("Enter the element to search: "))

print("\nArray:", arr)
print("Element to search:", target)

# Start execution time
start_time = time.perf_counter()

# Perform Binary Search
result = binary_search(arr, target)

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if result != -1:
    print(f"Element {target} found at index {result}")
else:
    print(f"Element {target} not found")

print("Execution Time: {:.10f} seconds".format(execution_time))

# Time Complexity
print("\n--- Time Complexity Analysis ---")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 8
# Enter the elements in sorted order:
# Element 1: 12
# Element 2: 21
# Element 3: 26
# Element 4: 46
# Element 5: 59
# Element 6: 61
# Element 7: 76
# Element 8: 88
# Enter the element to search: 59
#
# Array: [12, 21, 26, 46, 59, 61, 76, 88]
# Element to search: 59
# Element 59 found at index 4
# Execution Time: 0.0000699000 seconds
#
# --- Time Complexity Analysis ---
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
# Space Complexity: O(1)
