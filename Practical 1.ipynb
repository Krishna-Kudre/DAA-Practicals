# %%
import time

# Bubble Sort Function
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr


# Selection Sort Function
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr


# User Input
n = int(input("Enter the number of elements: "))
arr = []

print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

print("\nOriginal Array:", arr)

# Bubble Sort
bubble_arr = arr.copy()
start = time.perf_counter()
bubble_sort(bubble_arr)
end = time.perf_counter()

print("\n===== Bubble Sort =====")
print("Sorted Array:", bubble_arr)
print("Best Time Complexity   : O(n)")
print("Average Time Complexity: O(n²)")
print("Worst Time Complexity  : O(n²)")
print("Execution Time: {:.10f} seconds".format(end - start))

# Selection Sort
selection_arr = arr.copy()
start = time.perf_counter()
selection_sort(selection_arr)
end = time.perf_counter()

print("\n===== Selection Sort =====")
print("Sorted Array:", selection_arr)
print("Best Time Complexity   : O(n²)")
print("Average Time Complexity: O(n²)")
print("Worst Time Complexity  : O(n²)")
print("Execution Time: {:.10f} seconds".format(end - start))
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 21
# 56
# 34
# 12
# 6
#
# Original Array: [21, 56, 34, 12, 6]
#
# ===== Bubble Sort =====
# Sorted Array: [6, 12, 21, 34, 56]
# Best Time Complexity   : O(n)
# Average Time Complexity: O(n²)
# Worst Time Complexity  : O(n²)
# Execution Time: 0.0000715150 seconds
#
# ===== Selection Sort =====
# Sorted Array: [6, 12, 21, 34, 56]
# Best Time Complexity   : O(n²)
# Average Time Complexity: O(n²)
# Worst Time Complexity  : O(n²)
# Execution Time: 0.0000563340 seconds

# %%
import time

# Insertion Sort Function
def insertion_sort(arr):
    n = len(arr)

    for i in range(1, n):
        key = arr[i]
        j = i - 1

        # Move elements greater than key one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        # Insert key at the correct position
        arr[j + 1] = key


# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    value = int(input(f"Element {i + 1}: "))
    arr.append(value)

print("\nOriginal Array:", arr)

# Start execution time
start_time = time.perf_counter()

# Call Insertion Sort
insertion_sort(arr)

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = end_time - start_time

print("Sorted Array:", arr)
print("Execution Time: {:.10f} seconds".format(execution_time))

# Time Complexity Analysis
print("\n--- Time Complexity Analysis ---")
print("Best Case    : O(n)")
print("Average Case : O(n^2)")
print("Worst Case   : O(n^2)")
# Out:
# Enter the number of elements: 4
# Enter the elements:
# Element 1: 12
# Element 2: 21
# Element 3: 6
# Element 4: 9
#
# Original Array: [12, 21, 6, 9]
# Sorted Array: [6, 9, 12, 21]
# Execution Time: 0.0001331800 seconds
#
# --- Time Complexity Analysis ---
# Best Case    : O(n)
# Average Case : O(n^2)
# Worst Case   : O(n^2)

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2  # Finding the mid of the array
        L = arr[:mid]        # Dividing the array elements
        R = arr[mid:]        # into two halves

        merge_sort(L)        # Sorting the first half
        merge_sort(R)        # Sorting the second half

        i = j = k = 0

        # Copy data to temp arrays L[] and R[]
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        # Checking if any element was left
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
    return arr

# %%
# Merge Sort
merge_arr = arr.copy()
start = time.perf_counter()
merge_sort(merge_arr)
end = time.perf_counter()

print("\n===== Merge Sort =====")
print("Sorted Array:", merge_arr)
print("Best Time Complexity   : O(n log n)")
print("Average Time Complexity: O(n log n)")
print("Worst Time Complexity  : O(n log n)")
print("Execution Time: {:.10f} seconds".format(end - start))
# Out:
# ===== Merge Sort =====
# Sorted Array: [6, 12, 21, 34, 56]
# Best Time Complexity   : O(n log n)
# Average Time Complexity: O(n log n)
# Worst Time Complexity  : O(n log n)
# Execution Time: 0.0000794270 seconds

# %%
# Quick Sort Execution
quick_arr = arr.copy()
size = len(quick_arr)
start = time.perf_counter()
quick_sort(quick_arr, 0, size - 1)
end = time.perf_counter()

print("\n===== Quick Sort =====")
print("Sorted Array:", quick_arr)
print("Best Time Complexity   : O(n log n)")
print("Average Time Complexity: O(n log n)")
print("Worst Time Complexity  : O(n²)")
print("Execution Time: {:.10f} seconds".format(end - start))
# Out:
# ===== Quick Sort =====
# Sorted Array: [6, 12, 21, 34, 56]
# Best Time Complexity   : O(n log n)
# Average Time Complexity: O(n log n)
# Worst Time Complexity  : O(n²)
# Execution Time: 0.0000868590 seconds
